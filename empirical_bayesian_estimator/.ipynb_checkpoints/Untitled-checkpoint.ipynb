# %%
import pandas
import matplotlib.pyplot as plt

# %%
df=pandas.read_csv('result1.csv')
df.head()
# Out:
#   string  occurance   result      prob
# 0    '0'       6671   p(1|0)  0.077351
# 1    '1'        827   p(1|1)  0.375962
# 2   '00'       6154  p(1|00)  0.067111
# 3   '01'        516  p(1|01)  0.306242
# 4   '10'        516  p(1|10)  0.199541

# %%
plt.scatter(range(len(list(df.prob[1024:2046])),df.prob[1022:2046]))
list(df.prob[1022:2046])
# Out:
# [0.029207280530196705,
#  0.12030960161481515,
#  0.04477052690181435,
#  0.421333512459706,
#  0.22793031933162525,
#  0.16469830167739974,
#  3.76612860633633e-05,
#  0.2727710569486028,
#  0.09564175391356244,
#  0.15204605016032666,
#  0.14278427349978393,
#  0.00954895251988575,
#  0.3662078032705247,
#  0.7228665897015354,
#  0.2517356576502872,
#  0.3384760668625961,
#  0.0734446678977501,
#  0.09090773234763476,
#  0.5329982047275814,
#  0.3749084212170456,
#  1.3986169330567374e-05,
#  0.006176938837368386,
#  2.901428616877042e-06,
#  0.1163010713559402,
#  0.4166556990715252,
#  9.743506596868013e-06,
#  0.8350500614800921,
#  0.34856079142126545,
#  0.14109739188451526,
#  0.997983136998463,
#  0.00031681690932575834,
#  0.4976690382172462,
#  0.07339819171220058,
#  0.273036436875214,
#  0.00011891023917862984,
#  0.04404780460335843,
#  0.0018523657640237441,
#  3.787862820020498e-05,
#  0.1967323063443291,
#  0.004683899610580091,
#  0.22479075801393308,
# ...
